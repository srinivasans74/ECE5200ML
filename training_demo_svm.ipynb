# %% [markdown]
# # SVC+ SVM

# %%
import numpy as np
import pickle
import bz2
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn import svm

# %%
# load training data
Xtr_loadpath = 'Xtr.csv'
Xts_loadpath = 'Xts.csv'
ytr_loadpath = 'ytr.csv'


Xtr = np.loadtxt(Xtr_loadpath, delimiter=",")
Xts = np.loadtxt(Xts_loadpath, delimiter=",")
ytr = np.loadtxt(ytr_loadpath, delimiter=",")

num_features = Xtr.shape[1]
num_samples = Xtr.shape[0]
print(num_features)
print(num_samples)
# Out:
# 16
# 10000

# %%
from scipy.stats import skew
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer

# Assuming X is your dataset
#normalizer = Normalizer()
#X_normalized = normalizer.fit_transform(Xtr)
#scaler = MinMaxScaler()
#X_scaled = scaler.fit_transform(X)

scaler=StandardScaler()
xmean=np.mean(Xtr,axis=0)
xstd=np.std(Xtr,axis=0)
Xtr_standardized = (Xtr-xmean[None,:])/xstd[None,:]
Xts_standardized = (Xts-xmean[None,:])/xstd[None,:]
#Xtr_standardized=scaler.fit_transform(Xtr)
#Xts_standardized=scaler.fit_transform(Xts)



# save the standardized training data
Xtr_savepath = 'Xtr_sklearn.csv'
Xts_savepath = 'Xts_sklearn.csv'
yts_hat_savepath = 'yts_hat_sklearn.csv'

np.savetxt(Xtr_savepath, Xtr_standardized, delimiter=",")
np.savetxt(Xts_savepath, Xts_standardized, delimiter=",")

X_train, X_test, y_train, y_test = train_test_split(Xtr_standardized, ytr, test_size=0.20, shuffle=True)

# %%
# TODO:  Create a classifier: a support vector classifier
svc_n = svm.LinearSVC(penalty='l1',C=1, multi_class='ovr',max_iter=10000,loss='squared_hinge',dual=False)
svc_n.fit(X_train,y_train)
yhat_ts_n = svc_n.predict(X_test)
acc_ts_n = np.mean(yhat_ts_n== y_test)
print('Accuracy on test data = {0:f}'.format(acc_ts_n))
# Out:
# Accuracy on test data = 0.707000

# %%
svc_c = svm.LinearSVC(C=100, multi_class='crammer_singer',max_iter=100000,loss='squared_hinge')
svc_c.fit(X_train,y_train)
yhat_ts_c = svc_c.predict(X_test)
acc_ts_c = np.mean(yhat_ts_c== y_test)
print('Accuracy on test data = {0:f}'.format(acc_ts_c))
# Out:
# Accuracy on test data = 0.782500
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
svc_rb = svm.SVC(kernel="rbf", C=1, gamma=1, verbose=1)
svc_rb.fit(X_train,y_train)
yhat_ts_c = svc_rb.predict(X_test)
acc_ts_c = np.mean(yhat_ts_c== y_test)
print('Accuracy on test data = {0:f}'.format(acc_ts_c))
# Out:
# [LibSVM]Accuracy on test data = 0.887500

# %%
num_total_samples = len(X_train)+len(X_test)
test_fold = np.full(num_total_samples, -1)
test_fold[len(X_test):] = 0
x = np.vstack((X_train,X_test))
y = np.hstack((y_train,y_test))
ps = PredefinedSplit(test_fold)
print((test_fold))

ps = PredefinedSplit(test_fold)
#kf = KFold(...)

#C_test = [0.1, 1, 10,100]
#gam_test = [0.001, 0.01, 0.1]
C_test = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
gam_test = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
svc_rb = svm.SVC(kernel="sigmoid", C=0.01, gamma=1, verbose=0)

parameters={'C':C_test,'gamma':gam_test,'kernel':['sigmoid']}
gscv = GridSearchCV(svc_rb,cv=ps,param_grid=parameters,verbose=0)
gscv.fit(x,y)

# TODO:  Print the best parameter and score of the classifier
print(f'Best Param = {gscv.best_params_}')
print(f'Best score = {gscv.best_score_}')
#print(gscv.best_params_['C'])
#print(gscv.best_params_['gamma'])
svc_rb = svm.SVC(kernel="sigmoid", C=gscv.best_params_['C'], gamma=gscv.best_params_['gamma'], verbose=0)
svc_rb.fit(X_train,y_train)
yhat_ts = svc_rb.predict(X_test)
acc_ts = np.mean(yhat_ts== y_test)
print('Accuracy = {0:f}'.format(acc_ts))
# Out:
# [-1 -1 -1 ...  0  0  0]
# Fitting 1 folds for each of 49 candidates, totalling 49 fits
# [CV 1/1; 1/49] START C=0.001, gamma=0.0001, kernel=sigmoid......................
# [LibSVM][CV 1/1; 1/49] END ....C=0.001, gamma=0.0001, kernel=sigmoid; total time=   4.3s
# [CV 1/1; 2/49] START C=0.001, gamma=0.001, kernel=sigmoid.......................
# [LibSVM][CV 1/1; 2/49] END .....C=0.001, gamma=0.001, kernel=sigmoid; total time=   3.2s
# [CV 1/1; 3/49] START C=0.001, gamma=0.01, kernel=sigmoid........................
# [LibSVM][CV 1/1; 3/49] END ......C=0.001, gamma=0.01, kernel=sigmoid; total time=   3.6s
# [CV 1/1; 4/49] START C=0.001, gamma=0.1, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 4/49] END .......C=0.001, gamma=0.1, kernel=sigmoid; total time=   4.2s
# [CV 1/1; 5/49] START C=0.001, gamma=1, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 5/49] END .........C=0.001, gamma=1, kernel=sigmoid; total time=   5.3s
# [CV 1/1; 6/49] START C=0.001, gamma=10, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 6/49] END ........C=0.001, gamma=10, kernel=sigmoid; total time=   4.3s
# [CV 1/1; 7/49] START C=0.001, gamma=100, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 7/49] END .......C=0.001, gamma=100, kernel=sigmoid; total time=   3.2s
# [CV 1/1; 8/49] START C=0.01, gamma=0.0001, kernel=sigmoid.......................
# [LibSVM][CV 1/1; 8/49] END .....C=0.01, gamma=0.0001, kernel=sigmoid; total time=   3.8s
# [CV 1/1; 9/49] START C=0.01, gamma=0.001, kernel=sigmoid........................
# [LibSVM][CV 1/1; 9/49] END ......C=0.01, gamma=0.001, kernel=sigmoid; total time=   3.6s
# [CV 1/1; 10/49] START C=0.01, gamma=0.01, kernel=sigmoid........................
# [LibSVM][CV 1/1; 10/49] END ......C=0.01, gamma=0.01, kernel=sigmoid; total time=   3.8s
# [CV 1/1; 11/49] START C=0.01, gamma=0.1, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 11/49] END .......C=0.01, gamma=0.1, kernel=sigmoid; total time=   4.1s
# [CV 1/1; 12/49] START C=0.01, gamma=1, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 12/49] END .........C=0.01, gamma=1, kernel=sigmoid; total time=   5.6s
# [CV 1/1; 13/49] START C=0.01, gamma=10, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 13/49] END ........C=0.01, gamma=10, kernel=sigmoid; total time=   4.9s
# [CV 1/1; 14/49] START C=0.01, gamma=100, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 14/49] END .......C=0.01, gamma=100, kernel=sigmoid; total time=   3.4s
# [CV 1/1; 15/49] START C=0.1, gamma=0.0001, kernel=sigmoid.......................
# [LibSVM][CV 1/1; 15/49] END .....C=0.1, gamma=0.0001, kernel=sigmoid; total time=   3.6s
# [CV 1/1; 16/49] START C=0.1, gamma=0.001, kernel=sigmoid........................
# [LibSVM][CV 1/1; 16/49] END ......C=0.1, gamma=0.001, kernel=sigmoid; total time=   3.8s
# [CV 1/1; 17/49] START C=0.1, gamma=0.01, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 17/49] END .......C=0.1, gamma=0.01, kernel=sigmoid; total time=   5.0s
# [CV 1/1; 18/49] START C=0.1, gamma=0.1, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 18/49] END ........C=0.1, gamma=0.1, kernel=sigmoid; total time=   3.6s
# [CV 1/1; 19/49] START C=0.1, gamma=1, kernel=sigmoid............................
# [LibSVM][CV 1/1; 19/49] END ..........C=0.1, gamma=1, kernel=sigmoid; total time=   5.8s
# [CV 1/1; 20/49] START C=0.1, gamma=10, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 20/49] END .........C=0.1, gamma=10, kernel=sigmoid; total time=   4.3s
# [CV 1/1; 21/49] START C=0.1, gamma=100, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 21/49] END ........C=0.1, gamma=100, kernel=sigmoid; total time=   4.0s
# [CV 1/1; 22/49] START C=1, gamma=0.0001, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 22/49] END .......C=1, gamma=0.0001, kernel=sigmoid; total time=   3.4s
# [CV 1/1; 23/49] START C=1, gamma=0.001, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 23/49] END ........C=1, gamma=0.001, kernel=sigmoid; total time=   4.4s
# [CV 1/1; 24/49] START C=1, gamma=0.01, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 24/49] END .........C=1, gamma=0.01, kernel=sigmoid; total time=   3.0s
# [CV 1/1; 25/49] START C=1, gamma=0.1, kernel=sigmoid............................
# [LibSVM][CV 1/1; 25/49] END ..........C=1, gamma=0.1, kernel=sigmoid; total time=   3.0s
# [CV 1/1; 26/49] START C=1, gamma=1, kernel=sigmoid..............................
# [LibSVM][CV 1/1; 26/49] END ............C=1, gamma=1, kernel=sigmoid; total time=   5.2s
# [CV 1/1; 27/49] START C=1, gamma=10, kernel=sigmoid.............................
# [LibSVM][CV 1/1; 27/49] END ...........C=1, gamma=10, kernel=sigmoid; total time=   3.3s
# [CV 1/1; 28/49] START C=1, gamma=100, kernel=sigmoid............................
# [LibSVM][CV 1/1; 28/49] END ..........C=1, gamma=100, kernel=sigmoid; total time=   3.3s
# [CV 1/1; 29/49] START C=10, gamma=0.0001, kernel=sigmoid........................
# [LibSVM][CV 1/1; 29/49] END ......C=10, gamma=0.0001, kernel=sigmoid; total time=   3.1s
# [CV 1/1; 30/49] START C=10, gamma=0.001, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 30/49] END .......C=10, gamma=0.001, kernel=sigmoid; total time=   3.8s
# [CV 1/1; 31/49] START C=10, gamma=0.01, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 31/49] END ........C=10, gamma=0.01, kernel=sigmoid; total time=   2.5s
# [CV 1/1; 32/49] START C=10, gamma=0.1, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 32/49] END .........C=10, gamma=0.1, kernel=sigmoid; total time=   2.8s
# [CV 1/1; 33/49] START C=10, gamma=1, kernel=sigmoid.............................
# [LibSVM][CV 1/1; 33/49] END ...........C=10, gamma=1, kernel=sigmoid; total time=   4.8s
# [CV 1/1; 34/49] START C=10, gamma=10, kernel=sigmoid............................
# [LibSVM][CV 1/1; 34/49] END ..........C=10, gamma=10, kernel=sigmoid; total time=   4.5s
# [CV 1/1; 35/49] START C=10, gamma=100, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 35/49] END .........C=10, gamma=100, kernel=sigmoid; total time=   3.7s
# [CV 1/1; 36/49] START C=100, gamma=0.0001, kernel=sigmoid.......................
# [LibSVM][CV 1/1; 36/49] END .....C=100, gamma=0.0001, kernel=sigmoid; total time=   2.5s
# [CV 1/1; 37/49] START C=100, gamma=0.001, kernel=sigmoid........................
# [LibSVM][CV 1/1; 37/49] END ......C=100, gamma=0.001, kernel=sigmoid; total time=   1.9s
# [CV 1/1; 38/49] START C=100, gamma=0.01, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 38/49] END .......C=100, gamma=0.01, kernel=sigmoid; total time=   1.2s
# [CV 1/1; 39/49] START C=100, gamma=0.1, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 39/49] END ........C=100, gamma=0.1, kernel=sigmoid; total time=   1.5s
# [CV 1/1; 40/49] START C=100, gamma=1, kernel=sigmoid............................
# [LibSVM][CV 1/1; 40/49] END ..........C=100, gamma=1, kernel=sigmoid; total time=   3.0s
# [CV 1/1; 41/49] START C=100, gamma=10, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 41/49] END .........C=100, gamma=10, kernel=sigmoid; total time=   2.3s
# [CV 1/1; 42/49] START C=100, gamma=100, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 42/49] END ........C=100, gamma=100, kernel=sigmoid; total time=   1.7s
# [CV 1/1; 43/49] START C=1000, gamma=0.0001, kernel=sigmoid......................
# [LibSVM][CV 1/1; 43/49] END ....C=1000, gamma=0.0001, kernel=sigmoid; total time=   1.6s
# [CV 1/1; 44/49] START C=1000, gamma=0.001, kernel=sigmoid.......................
# [LibSVM][CV 1/1; 44/49] END .....C=1000, gamma=0.001, kernel=sigmoid; total time=   1.3s
# [CV 1/1; 45/49] START C=1000, gamma=0.01, kernel=sigmoid........................
# [LibSVM][CV 1/1; 45/49] END ......C=1000, gamma=0.01, kernel=sigmoid; total time=   1.1s
# [CV 1/1; 46/49] START C=1000, gamma=0.1, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 46/49] END .......C=1000, gamma=0.1, kernel=sigmoid; total time=   1.5s
# [CV 1/1; 47/49] START C=1000, gamma=1, kernel=sigmoid...........................
# [LibSVM][CV 1/1; 47/49] END .........C=1000, gamma=1, kernel=sigmoid; total time=   3.0s
# [CV 1/1; 48/49] START C=1000, gamma=10, kernel=sigmoid..........................
# [LibSVM][CV 1/1; 48/49] END ........C=1000, gamma=10, kernel=sigmoid; total time=   3.2s
# [CV 1/1; 49/49] START C=1000, gamma=100, kernel=sigmoid.........................
# [LibSVM][CV 1/1; 49/49] END .......C=1000, gamma=100, kernel=sigmoid; total time=   2.2s
# [LibSVM]Best Param = {'C': 1000, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Best score = 0.81525
# [LibSVM]Accuracy = 0.852500

# %%
# TODO:  Create a pre-defined test split object 
from sklearn.model_selection import PredefinedSplit

num_total_samples = len(X_train)+len(X_test)
test_fold = np.full(num_total_samples, -1)
test_fold[len(X_test):] = 0
x = np.vstack((X_train,X_test))
y = np.hstack((y_train,y_test))
ps = PredefinedSplit(test_fold)
print((test_fold))

ps = PredefinedSplit(test_fold)
#kf = KFold(...)

#C_test = [0.1, 1, 10,100]
#gam_test = [0.001, 0.01, 0.1]
C_test = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
gam_test = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
svc_rb = svm.SVC(kernel="linear", C=0.01, gamma=1, verbose=0)

parameters={'C':C_test,'gamma':gam_test,'kernel':['linear']}
gscv = GridSearchCV(svc_rb,cv=ps,param_grid=parameters,verbose=0)
gscv.fit(x,y)

# TODO:  Print the best parameter and score of the classifier
print(f'Best Param = {gscv.best_params_}')
print(f'Best score = {gscv.best_score_}')
#print(gscv.best_params_['C'])
#print(gscv.best_params_['gamma'])
svc_rb = svm.SVC(kernel="linear", C=gscv.best_params_['C'], gamma=gscv.best_params_['gamma'], verbose=0)
svc_rb.fit(X_train,y_train)
yhat_ts = svc_rb.predict(X_test)
acc_ts = np.mean(yhat_ts== y_test)
print('Accuracy = {0:f}'.format(acc_ts))

# %%
# TODO:  Create a pre-defined test split object 
from sklearn.model_selection import PredefinedSplit

num_total_samples = len(X_train)+len(X_test)
test_fold = np.full(num_total_samples, -1)
test_fold[len(X_test):] = 0
x = np.vstack((X_train,X_test))
y = np.hstack((y_train,y_test))
ps = PredefinedSplit(test_fold)
print((test_fold))

ps = PredefinedSplit(test_fold)
#kf = KFold(...)

#C_test = [0.1, 1, 10,100]
#gam_test = [0.001, 0.01, 0.1]
C_test = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
gam_test = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
svc_rb = svm.SVC(kernel="poly", C=0.01, gamma=1, verbose=0)

parameters={'C':C_test,'gamma':gam_test,'kernel':['poly']}
gscv = GridSearchCV(svc_rb,cv=ps,param_grid=parameters,verbose=0)
gscv.fit(x,y)

# TODO:  Print the best parameter and score of the classifier
print(f'Best Param = {gscv.best_params_}')
print(f'Best score = {gscv.best_score_}')
#print(gscv.best_params_['C'])
#print(gscv.best_params_['gamma'])
svc_rb = svm.SVC(kernel="poly", C=gscv.best_params_['C'], gamma=gscv.best_params_['gamma'], verbose=0)
svc_rb.fit(X_train,y_train)
yhat_ts = svc_rb.predict(X_test)
acc_ts = np.mean(yhat_ts== y_test)
print('Accuracy = {0:f}'.format(acc_ts))
# Out:
# [-1 -1 -1 ...  0  0  0]
# Fitting 1 folds for each of 49 candidates, totalling 49 fits
# [CV 1/1; 1/49] START C=0.001, gamma=0.0001, kernel=poly.........................
# [LibSVM][CV 1/1; 1/49] END .......C=0.001, gamma=0.0001, kernel=poly; total time=   3.2s
# [CV 1/1; 2/49] START C=0.001, gamma=0.001, kernel=poly..........................
# [LibSVM][CV 1/1; 2/49] END ........C=0.001, gamma=0.001, kernel=poly; total time=   3.5s
# [CV 1/1; 3/49] START C=0.001, gamma=0.01, kernel=poly...........................
# [LibSVM][CV 1/1; 3/49] END .........C=0.001, gamma=0.01, kernel=poly; total time=   2.5s
# [CV 1/1; 4/49] START C=0.001, gamma=0.1, kernel=poly............................
# [LibSVM][CV 1/1; 4/49] END ..........C=0.001, gamma=0.1, kernel=poly; total time=   3.3s
# [CV 1/1; 5/49] START C=0.001, gamma=1, kernel=poly..............................
# [LibSVM][CV 1/1; 5/49] END ............C=0.001, gamma=1, kernel=poly; total time=   1.6s
# [CV 1/1; 6/49] START C=0.001, gamma=10, kernel=poly.............................
# [LibSVM][CV 1/1; 6/49] END ...........C=0.001, gamma=10, kernel=poly; total time=   1.3s
# [CV 1/1; 7/49] START C=0.001, gamma=100, kernel=poly............................
# [LibSVM][CV 1/1; 7/49] END ..........C=0.001, gamma=100, kernel=poly; total time=   2.1s
# [CV 1/1; 8/49] START C=0.01, gamma=0.0001, kernel=poly..........................
# [LibSVM][CV 1/1; 8/49] END ........C=0.01, gamma=0.0001, kernel=poly; total time=   2.9s
# [CV 1/1; 9/49] START C=0.01, gamma=0.001, kernel=poly...........................
# [LibSVM][CV 1/1; 9/49] END .........C=0.01, gamma=0.001, kernel=poly; total time=   3.6s
# [CV 1/1; 10/49] START C=0.01, gamma=0.01, kernel=poly...........................
# [LibSVM][CV 1/1; 10/49] END .........C=0.01, gamma=0.01, kernel=poly; total time=   2.5s
# [CV 1/1; 11/49] START C=0.01, gamma=0.1, kernel=poly............................
# [LibSVM][CV 1/1; 11/49] END ..........C=0.01, gamma=0.1, kernel=poly; total time=   3.1s
# [CV 1/1; 12/49] START C=0.01, gamma=1, kernel=poly..............................
# [LibSVM][CV 1/1; 12/49] END ............C=0.01, gamma=1, kernel=poly; total time=   1.7s
# [CV 1/1; 13/49] START C=0.01, gamma=10, kernel=poly.............................
# [LibSVM][CV 1/1; 13/49] END ...........C=0.01, gamma=10, kernel=poly; total time=   2.5s
# [CV 1/1; 14/49] START C=0.01, gamma=100, kernel=poly............................
# [LibSVM][CV 1/1; 14/49] END ..........C=0.01, gamma=100, kernel=poly; total time=   1.9s
# [CV 1/1; 15/49] START C=0.1, gamma=0.0001, kernel=poly..........................
# [LibSVM][CV 1/1; 15/49] END ........C=0.1, gamma=0.0001, kernel=poly; total time=   3.0s
# [CV 1/1; 16/49] START C=0.1, gamma=0.001, kernel=poly...........................
# [LibSVM][CV 1/1; 16/49] END .........C=0.1, gamma=0.001, kernel=poly; total time=   3.9s
# [CV 1/1; 17/49] START C=0.1, gamma=0.01, kernel=poly............................
# [LibSVM][CV 1/1; 17/49] END ..........C=0.1, gamma=0.01, kernel=poly; total time=   2.1s
# [CV 1/1; 18/49] START C=0.1, gamma=0.1, kernel=poly.............................
# [LibSVM][CV 1/1; 18/49] END ...........C=0.1, gamma=0.1, kernel=poly; total time=   2.9s
# [CV 1/1; 19/49] START C=0.1, gamma=1, kernel=poly...............................
# [LibSVM][CV 1/1; 19/49] END .............C=0.1, gamma=1, kernel=poly; total time=   2.2s
# [CV 1/1; 20/49] START C=0.1, gamma=10, kernel=poly..............................
# [LibSVM][CV 1/1; 20/49] END ............C=0.1, gamma=10, kernel=poly; total time=   1.5s
# [CV 1/1; 21/49] START C=0.1, gamma=100, kernel=poly.............................
# [LibSVM][CV 1/1; 21/49] END ...........C=0.1, gamma=100, kernel=poly; total time=   2.0s
# [CV 1/1; 22/49] START C=1, gamma=0.0001, kernel=poly............................
# [LibSVM][CV 1/1; 22/49] END ..........C=1, gamma=0.0001, kernel=poly; total time=   2.8s
# [CV 1/1; 23/49] START C=1, gamma=0.001, kernel=poly.............................
# [LibSVM][CV 1/1; 23/49] END ...........C=1, gamma=0.001, kernel=poly; total time=   3.3s
# [CV 1/1; 24/49] START C=1, gamma=0.01, kernel=poly..............................
# [LibSVM][CV 1/1; 24/49] END ............C=1, gamma=0.01, kernel=poly; total time=   3.4s
# [CV 1/1; 25/49] START C=1, gamma=0.1, kernel=poly...............................
# [LibSVM][CV 1/1; 25/49] END .............C=1, gamma=0.1, kernel=poly; total time=   2.3s
# [CV 1/1; 26/49] START C=1, gamma=1, kernel=poly.................................
# [LibSVM][CV 1/1; 26/49] END ...............C=1, gamma=1, kernel=poly; total time=   2.1s
# [CV 1/1; 27/49] START C=1, gamma=10, kernel=poly................................
# [LibSVM][CV 1/1; 27/49] END ..............C=1, gamma=10, kernel=poly; total time=   1.8s
# [CV 1/1; 28/49] START C=1, gamma=100, kernel=poly...............................
# [LibSVM][CV 1/1; 28/49] END .............C=1, gamma=100, kernel=poly; total time=   1.5s
# [CV 1/1; 29/49] START C=10, gamma=0.0001, kernel=poly...........................
# [LibSVM][CV 1/1; 29/49] END .........C=10, gamma=0.0001, kernel=poly; total time=   4.1s
# [CV 1/1; 30/49] START C=10, gamma=0.001, kernel=poly............................
# [LibSVM][CV 1/1; 30/49] END ..........C=10, gamma=0.001, kernel=poly; total time=   3.0s
# [CV 1/1; 31/49] START C=10, gamma=0.01, kernel=poly.............................
# [LibSVM][CV 1/1; 31/49] END ...........C=10, gamma=0.01, kernel=poly; total time=   3.6s
# [CV 1/1; 32/49] START C=10, gamma=0.1, kernel=poly..............................
# [LibSVM][CV 1/1; 32/49] END ............C=10, gamma=0.1, kernel=poly; total time=   1.9s
# [CV 1/1; 33/49] START C=10, gamma=1, kernel=poly................................
# [LibSVM][CV 1/1; 33/49] END ..............C=10, gamma=1, kernel=poly; total time=   1.9s
# [CV 1/1; 34/49] START C=10, gamma=10, kernel=poly...............................
# [LibSVM][CV 1/1; 34/49] END .............C=10, gamma=10, kernel=poly; total time=   1.4s
# [CV 1/1; 35/49] START C=10, gamma=100, kernel=poly..............................
# [LibSVM][CV 1/1; 35/49] END ............C=10, gamma=100, kernel=poly; total time=   1.7s
# [CV 1/1; 36/49] START C=100, gamma=0.0001, kernel=poly..........................
# [LibSVM][CV 1/1; 36/49] END ........C=100, gamma=0.0001, kernel=poly; total time=   3.2s
# [CV 1/1; 37/49] START C=100, gamma=0.001, kernel=poly...........................
# [LibSVM][CV 1/1; 37/49] END .........C=100, gamma=0.001, kernel=poly; total time=   3.1s
# [CV 1/1; 38/49] START C=100, gamma=0.01, kernel=poly............................
# [LibSVM][CV 1/1; 38/49] END ..........C=100, gamma=0.01, kernel=poly; total time=   2.1s
# [CV 1/1; 39/49] START C=100, gamma=0.1, kernel=poly.............................
# [LibSVM][CV 1/1; 39/49] END ...........C=100, gamma=0.1, kernel=poly; total time=   2.1s
# [CV 1/1; 40/49] START C=100, gamma=1, kernel=poly...............................
# [LibSVM][CV 1/1; 40/49] END .............C=100, gamma=1, kernel=poly; total time=   1.8s
# [CV 1/1; 41/49] START C=100, gamma=10, kernel=poly..............................
# [LibSVM][CV 1/1; 41/49] END ............C=100, gamma=10, kernel=poly; total time=   2.4s
# [CV 1/1; 42/49] START C=100, gamma=100, kernel=poly.............................
# [LibSVM][CV 1/1; 42/49] END ...........C=100, gamma=100, kernel=poly; total time=   2.3s
# [CV 1/1; 43/49] START C=1000, gamma=0.0001, kernel=poly.........................
# [LibSVM][CV 1/1; 43/49] END .......C=1000, gamma=0.0001, kernel=poly; total time=   2.7s
# [CV 1/1; 44/49] START C=1000, gamma=0.001, kernel=poly..........................
# [LibSVM][CV 1/1; 44/49] END ........C=1000, gamma=0.001, kernel=poly; total time=   3.4s
# [CV 1/1; 45/49] START C=1000, gamma=0.01, kernel=poly...........................
# [LibSVM][CV 1/1; 45/49] END .........C=1000, gamma=0.01, kernel=poly; total time=   2.0s
# [CV 1/1; 46/49] START C=1000, gamma=0.1, kernel=poly............................
# [LibSVM][CV 1/1; 46/49] END ..........C=1000, gamma=0.1, kernel=poly; total time=   2.2s
# [CV 1/1; 47/49] START C=1000, gamma=1, kernel=poly..............................
# [LibSVM][CV 1/1; 47/49] END ............C=1000, gamma=1, kernel=poly; total time=   1.8s
# [CV 1/1; 48/49] START C=1000, gamma=10, kernel=poly.............................
# [LibSVM][CV 1/1; 48/49] END ...........C=1000, gamma=10, kernel=poly; total time=   2.4s
# [CV 1/1; 49/49] START C=1000, gamma=100, kernel=poly............................
# [LibSVM][CV 1/1; 49/49] END ..........C=1000, gamma=100, kernel=poly; total time=   2.0s
# [LibSVM]Best Param = {'C': 0.01, 'gamma': 1, 'kernel': 'poly'}
# Best score = 0.835625
# [LibSVM]Accuracy = 0.926500

# %%
from sklearn.model_selection import PredefinedSplit

num_total_samples = len(X_train)+len(X_test)
test_fold = np.full(num_total_samples, -1)
test_fold[len(X_test):] = 0
x = np.vstack((X_train,X_test))
y = np.hstack((y_train,y_test))
ps = PredefinedSplit(test_fold)
print((test_fold))

ps = PredefinedSplit(test_fold)
#kf = KFold(...)

#C_test = [0.1, 1, 10,100]
#gam_test = [0.001, 0.01, 0.1]
C_test = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
gam_test = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]

parameters={'C':C_test,'gamma':gam_test,'kernel':['rbf']}
gscv = GridSearchCV(svc_rb,cv=ps,param_grid=parameters,verbose=0)
gscv.fit(x,y)

# TODO:  Print the best parameter and score of the classifier
print(f'Best score = {gscv.best_params_}')
print(f'Best Param = {gscv.best_score_}')
# Out:
# [-1 -1 -1 ...  0  0  0]
# Fitting 1 folds for each of 49 candidates, totalling 49 fits
# [CV 1/1; 1/49] START C=0.001, gamma=0.0001, kernel=rbf..........................
# [LibSVM][CV 1/1; 1/49] END ........C=0.001, gamma=0.0001, kernel=rbf; total time=   2.2s
# [CV 1/1; 2/49] START C=0.001, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 1/1; 2/49] END .........C=0.001, gamma=0.001, kernel=rbf; total time=   2.0s
# [CV 1/1; 3/49] START C=0.001, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/1; 3/49] END ..........C=0.001, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 1/1; 4/49] START C=0.001, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 1/1; 4/49] END ...........C=0.001, gamma=0.1, kernel=rbf; total time=   2.1s
# [CV 1/1; 5/49] START C=0.001, gamma=1, kernel=rbf...............................
# [LibSVM][CV 1/1; 5/49] END .............C=0.001, gamma=1, kernel=rbf; total time=   2.2s
# [CV 1/1; 6/49] START C=0.001, gamma=10, kernel=rbf..............................
# [LibSVM][CV 1/1; 6/49] END ............C=0.001, gamma=10, kernel=rbf; total time=   2.3s
# [CV 1/1; 7/49] START C=0.001, gamma=100, kernel=rbf.............................
# [LibSVM][CV 1/1; 7/49] END ...........C=0.001, gamma=100, kernel=rbf; total time=   3.0s
# [CV 1/1; 8/49] START C=0.01, gamma=0.0001, kernel=rbf...........................
# [LibSVM][CV 1/1; 8/49] END .........C=0.01, gamma=0.0001, kernel=rbf; total time=   2.1s
# [CV 1/1; 9/49] START C=0.01, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 1/1; 9/49] END ..........C=0.01, gamma=0.001, kernel=rbf; total time=   2.1s
# [CV 1/1; 10/49] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/1; 10/49] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 1/1; 11/49] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 1/1; 11/49] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=   2.1s
# [CV 1/1; 12/49] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 1/1; 12/49] END .............C=0.01, gamma=1, kernel=rbf; total time=   2.0s
# [CV 1/1; 13/49] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 1/1; 13/49] END ............C=0.01, gamma=10, kernel=rbf; total time=   2.2s
# [CV 1/1; 14/49] START C=0.01, gamma=100, kernel=rbf.............................
# [LibSVM][CV 1/1; 14/49] END ...........C=0.01, gamma=100, kernel=rbf; total time=   3.0s
# [CV 1/1; 15/49] START C=0.1, gamma=0.0001, kernel=rbf...........................
# [LibSVM][CV 1/1; 15/49] END .........C=0.1, gamma=0.0001, kernel=rbf; total time=   2.1s
# [CV 1/1; 16/49] START C=0.1, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 1/1; 16/49] END ..........C=0.1, gamma=0.001, kernel=rbf; total time=   2.1s
# [CV 1/1; 17/49] START C=0.1, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 1/1; 17/49] END ...........C=0.1, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 1/1; 18/49] START C=0.1, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 1/1; 18/49] END ............C=0.1, gamma=0.1, kernel=rbf; total time=   1.9s
# [CV 1/1; 19/49] START C=0.1, gamma=1, kernel=rbf................................
# [LibSVM][CV 1/1; 19/49] END ..............C=0.1, gamma=1, kernel=rbf; total time=   2.1s
# [CV 1/1; 20/49] START C=0.1, gamma=10, kernel=rbf...............................
# [LibSVM][CV 1/1; 20/49] END .............C=0.1, gamma=10, kernel=rbf; total time=   2.2s
# [CV 1/1; 21/49] START C=0.1, gamma=100, kernel=rbf..............................
# [LibSVM][CV 1/1; 21/49] END ............C=0.1, gamma=100, kernel=rbf; total time=   2.8s
# [CV 1/1; 22/49] START C=1, gamma=0.0001, kernel=rbf.............................
# [LibSVM][CV 1/1; 22/49] END ...........C=1, gamma=0.0001, kernel=rbf; total time=   2.0s
# [CV 1/1; 23/49] START C=1, gamma=0.001, kernel=rbf..............................
# [LibSVM][CV 1/1; 23/49] END ............C=1, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV 1/1; 24/49] START C=1, gamma=0.01, kernel=rbf...............................
# [LibSVM][CV 1/1; 24/49] END .............C=1, gamma=0.01, kernel=rbf; total time=   1.9s
# [CV 1/1; 25/49] START C=1, gamma=0.1, kernel=rbf................................
# [LibSVM][CV 1/1; 25/49] END ..............C=1, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV 1/1; 26/49] START C=1, gamma=1, kernel=rbf..................................
# [LibSVM][CV 1/1; 26/49] END ................C=1, gamma=1, kernel=rbf; total time=   2.1s
# [CV 1/1; 27/49] START C=1, gamma=10, kernel=rbf.................................
# [LibSVM][CV 1/1; 27/49] END ...............C=1, gamma=10, kernel=rbf; total time=   2.3s
# [CV 1/1; 28/49] START C=1, gamma=100, kernel=rbf................................
# [LibSVM][CV 1/1; 28/49] END ..............C=1, gamma=100, kernel=rbf; total time=   2.8s
# [CV 1/1; 29/49] START C=10, gamma=0.0001, kernel=rbf............................
# [LibSVM][CV 1/1; 29/49] END ..........C=10, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV 1/1; 30/49] START C=10, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 1/1; 30/49] END ...........C=10, gamma=0.001, kernel=rbf; total time=   1.7s
# [CV 1/1; 31/49] START C=10, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 1/1; 31/49] END ............C=10, gamma=0.01, kernel=rbf; total time=   1.5s
# [CV 1/1; 32/49] START C=10, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 1/1; 32/49] END .............C=10, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV 1/1; 33/49] START C=10, gamma=1, kernel=rbf.................................
# [LibSVM][CV 1/1; 33/49] END ...............C=10, gamma=1, kernel=rbf; total time=   2.0s
# [CV 1/1; 34/49] START C=10, gamma=10, kernel=rbf................................
# [LibSVM][CV 1/1; 34/49] END ..............C=10, gamma=10, kernel=rbf; total time=   2.3s
# [CV 1/1; 35/49] START C=10, gamma=100, kernel=rbf...............................
# [LibSVM][CV 1/1; 35/49] END .............C=10, gamma=100, kernel=rbf; total time=   2.8s
# [CV 1/1; 36/49] START C=100, gamma=0.0001, kernel=rbf...........................
# [LibSVM][CV 1/1; 36/49] END .........C=100, gamma=0.0001, kernel=rbf; total time=   1.7s
# [CV 1/1; 37/49] START C=100, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 1/1; 37/49] END ..........C=100, gamma=0.001, kernel=rbf; total time=   1.3s
# [CV 1/1; 38/49] START C=100, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 1/1; 38/49] END ...........C=100, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV 1/1; 39/49] START C=100, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 1/1; 39/49] END ............C=100, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV 1/1; 40/49] START C=100, gamma=1, kernel=rbf................................
# [LibSVM][CV 1/1; 40/49] END ..............C=100, gamma=1, kernel=rbf; total time=   2.0s
# [CV 1/1; 41/49] START C=100, gamma=10, kernel=rbf...............................
# [LibSVM][CV 1/1; 41/49] END .............C=100, gamma=10, kernel=rbf; total time=   2.2s
# [CV 1/1; 42/49] START C=100, gamma=100, kernel=rbf..............................
# [LibSVM][CV 1/1; 42/49] END ............C=100, gamma=100, kernel=rbf; total time=   2.8s
# [CV 1/1; 43/49] START C=1000, gamma=0.0001, kernel=rbf..........................
# [LibSVM][CV 1/1; 43/49] END ........C=1000, gamma=0.0001, kernel=rbf; total time=   1.4s
# [CV 1/1; 44/49] START C=1000, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 1/1; 44/49] END .........C=1000, gamma=0.001, kernel=rbf; total time=   1.3s
# [CV 1/1; 45/49] START C=1000, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/1; 45/49] END ..........C=1000, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV 1/1; 46/49] START C=1000, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 1/1; 46/49] END ...........C=1000, gamma=0.1, kernel=rbf; total time=   1.7s
# [CV 1/1; 47/49] START C=1000, gamma=1, kernel=rbf...............................
# [LibSVM][CV 1/1; 47/49] END .............C=1000, gamma=1, kernel=rbf; total time=   2.0s
# [CV 1/1; 48/49] START C=1000, gamma=10, kernel=rbf..............................
# [LibSVM][CV 1/1; 48/49] END ............C=1000, gamma=10, kernel=rbf; total time=   2.2s
# [CV 1/1; 49/49] START C=1000, gamma=100, kernel=rbf.............................
# [LibSVM][CV 1/1; 49/49] END ...........C=1000, gamma=100, kernel=rbf; total time=   3.1s
# [LibSVM]Best score = {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Param = 0.892625

# %%
num_splits = 10  # Adjust as needed

# Create KFold object
kf = KFold(n_splits=num_splits, shuffle=True, random_state=42)
test_accuracies = []
svc_rb = svm.SVC(kernel="rbf", C=0.01, gamma=1, verbose=0)
C_test = [0.01, 0.01, 0.1, 1, 10]
gam_test = [0.01, 0.001, 0.01, 0.1, 1, 2]
parameters={'C':C_test,'gamma':gam_test,'kernel':['rbf']}
gscv = GridSearchCV(svc_rb,cv=kf,param_grid=parameters,verbose=0,n_jobs=-1)
gscv.fit(x,y)
print(f'Best score = {gscv.best_params_}')
print(f'Best Param = {gscv.best_score_}')
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV 1/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  22.6s
# [CV 2/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  20.6s
# [CV 3/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.8s
# [CV 4/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.3s
# [CV 5/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.1s
# [CV 6/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.0s
# [CV 7/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.9s
# [CV 8/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.0s
# [CV 9/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 1/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.0s
# [CV 10/10; 1/36] START C=0.01, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 1/36] END .........C=0.01, gamma=0.01, kernel=rbf; total time=  17.8s
# [CV 1/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 1/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  17.2s
# [CV 2/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 2/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  16.8s
# [CV 3/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 3/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  17.0s
# [CV 4/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 4/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  17.8s
# [CV 5/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 5/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  19.9s
# [CV 6/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 6/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  18.6s
# [CV 7/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 7/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  19.2s
# [CV 8/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 8/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  20.2s
# [CV 9/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 9/10; 2/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  18.0s
# [CV 10/10; 2/36] START C=0.01, gamma=0.001, kernel=rbf..........................
# [LibSVM][CV 10/10; 2/36] END ........C=0.01, gamma=0.001, kernel=rbf; total time=  18.7s
# [CV 1/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.2s
# [CV 2/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.7s
# [CV 3/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.7s
# [CV 4/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  20.8s
# [CV 5/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.8s
# [CV 6/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.3s
# [CV 7/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.7s
# [CV 8/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.3s
# [CV 9/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 3/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.1s
# [CV 10/10; 3/36] START C=0.01, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 3/36] END .........C=0.01, gamma=0.01, kernel=rbf; total time=  19.6s
# [CV 1/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 1/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  18.2s
# [CV 2/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 2/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  16.5s
# [CV 3/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 3/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  16.5s
# [CV 4/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 4/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  16.9s
# [CV 5/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 5/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  17.9s
# [CV 6/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 6/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  17.9s
# [CV 7/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 7/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  18.5s
# [CV 8/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 8/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  19.0s
# [CV 9/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 9/10; 4/36] END ...........C=0.01, gamma=0.1, kernel=rbf; total time=  17.7s
# [CV 10/10; 4/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 10/10; 4/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  19.6s
# [CV 1/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 1/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  19.5s
# [CV 2/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 2/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  19.2s
# [CV 3/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 3/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  18.1s
# [CV 4/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 4/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  18.9s
# [CV 5/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 5/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  20.2s
# [CV 6/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 6/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  19.1s
# [CV 7/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 7/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  19.0s
# [CV 8/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 8/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  19.2s
# [CV 9/10; 5/36] START C=0.01, gamma=1, kernel=rbf...............................
# [LibSVM][CV 9/10; 5/36] END .............C=0.01, gamma=1, kernel=rbf; total time=  17.4s
# [CV 10/10; 5/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 10/10; 5/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  18.0s
# [CV 1/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 1/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  19.9s
# [CV 2/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 2/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  18.5s
# [CV 3/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 3/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  17.8s
# [CV 4/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 4/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  17.7s
# [CV 5/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 5/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  18.3s
# [CV 6/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 6/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  19.7s
# [CV 7/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 7/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  18.1s
# [CV 8/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 8/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  18.2s
# [CV 9/10; 6/36] START C=0.01, gamma=10, kernel=rbf..............................
# [LibSVM][CV 9/10; 6/36] END ............C=0.01, gamma=10, kernel=rbf; total time=  18.8s
# [CV 10/10; 6/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 10/10; 6/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  18.4s
# [CV 1/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.5s
# [CV 2/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.7s
# [CV 3/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.6s
# [CV 4/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.4s
# [CV 5/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.8s
# [CV 6/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.7s
# [CV 7/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.5s
# [CV 8/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.8s
# [CV 9/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 7/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.8s
# [CV 10/10; 7/36] START C=0.01, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 7/36] END .........C=0.01, gamma=0.01, kernel=rbf; total time=  16.6s
# [CV 1/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 1/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  18.9s
# [CV 2/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 2/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  19.6s
# [CV 3/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 3/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  19.5s
# [CV 4/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 4/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  17.7s
# [CV 5/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 5/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  17.6s
# [CV 6/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 6/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  18.4s
# [CV 7/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 7/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  18.6s
# [CV 8/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 8/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  17.9s
# [CV 9/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 9/10; 8/36] END .........C=0.01, gamma=0.001, kernel=rbf; total time=  19.0s
# [CV 10/10; 8/36] START C=0.01, gamma=0.001, kernel=rbf..........................
# [LibSVM][CV 10/10; 8/36] END ........C=0.01, gamma=0.001, kernel=rbf; total time=  18.3s
# [CV 1/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.5s
# [CV 2/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.5s
# [CV 3/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.7s
# [CV 4/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.6s
# [CV 5/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.7s
# [CV 6/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.6s
# [CV 7/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  17.5s
# [CV 8/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  18.6s
# [CV 9/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 9/36] END ..........C=0.01, gamma=0.01, kernel=rbf; total time=  16.9s
# [CV 10/10; 9/36] START C=0.01, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 9/36] END .........C=0.01, gamma=0.01, kernel=rbf; total time=  16.9s
# [CV 1/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 1/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  17.2s
# [CV 2/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 2/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  18.6s
# [CV 3/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 3/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  20.2s
# [CV 4/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 4/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  18.7s
# [CV 5/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 5/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  20.5s
# [CV 6/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 6/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  18.5s
# [CV 7/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 7/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  18.4s
# [CV 8/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 8/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  18.4s
# [CV 9/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 9/10; 10/36] END ..........C=0.01, gamma=0.1, kernel=rbf; total time=  19.1s
# [CV 10/10; 10/36] START C=0.01, gamma=0.1, kernel=rbf...........................
# [LibSVM][CV 10/10; 10/36] END .........C=0.01, gamma=0.1, kernel=rbf; total time=  21.0s
# [CV 1/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 1/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  21.6s
# [CV 2/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 2/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  19.0s
# [CV 3/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 3/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  18.9s
# [CV 4/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 4/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  19.2s
# [CV 5/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 5/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  15.2s
# [CV 6/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 6/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  10.8s
# [CV 7/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 7/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  11.4s
# [CV 8/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 8/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  10.4s
# [CV 9/10; 11/36] START C=0.01, gamma=1, kernel=rbf..............................
# [LibSVM][CV 9/10; 11/36] END ............C=0.01, gamma=1, kernel=rbf; total time=  10.6s
# [CV 10/10; 11/36] START C=0.01, gamma=1, kernel=rbf.............................
# [LibSVM][CV 10/10; 11/36] END ...........C=0.01, gamma=1, kernel=rbf; total time=  10.5s
# [CV 1/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 1/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  10.9s
# [CV 2/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 2/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  10.9s
# [CV 3/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 3/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.0s
# [CV 4/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 4/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.5s
# [CV 5/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 5/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.9s
# [CV 6/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 6/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.3s
# [CV 7/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 7/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.3s
# [CV 8/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 8/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.2s
# [CV 9/10; 12/36] START C=0.01, gamma=10, kernel=rbf.............................
# [LibSVM][CV 9/10; 12/36] END ...........C=0.01, gamma=10, kernel=rbf; total time=  11.1s
# [CV 10/10; 12/36] START C=0.01, gamma=10, kernel=rbf............................
# [LibSVM][CV 10/10; 12/36] END ..........C=0.01, gamma=10, kernel=rbf; total time=  12.0s
# [CV 1/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.4s
# [CV 2/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.1s
# [CV 3/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.1s
# [CV 4/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   6.8s
# [CV 5/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.0s
# [CV 6/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.0s
# [CV 7/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   6.9s
# [CV 8/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.4s
# [CV 9/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 13/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   8.8s
# [CV 10/10; 13/36] START C=0.1, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 13/36] END .........C=0.1, gamma=0.01, kernel=rbf; total time=   9.9s
# [CV 1/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 1/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  14.5s
# [CV 2/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 2/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  11.9s
# [CV 3/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 3/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  10.9s
# [CV 4/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 4/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  11.0s
# [CV 5/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 5/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  11.8s
# [CV 6/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 6/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  12.0s
# [CV 7/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 7/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  12.2s
# [CV 8/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 8/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  11.2s
# [CV 9/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 9/10; 14/36] END .........C=0.1, gamma=0.001, kernel=rbf; total time=  10.8s
# [CV 10/10; 14/36] START C=0.1, gamma=0.001, kernel=rbf..........................
# [LibSVM][CV 10/10; 14/36] END ........C=0.1, gamma=0.001, kernel=rbf; total time=  11.1s
# [CV 1/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   6.9s
# [CV 2/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.0s
# [CV 3/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.6s
# [CV 4/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.3s
# [CV 5/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.5s
# [CV 6/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.1s
# [CV 7/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.6s
# [CV 8/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.5s
# [CV 9/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 15/36] END ..........C=0.1, gamma=0.01, kernel=rbf; total time=   7.9s
# [CV 10/10; 15/36] START C=0.1, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 15/36] END .........C=0.1, gamma=0.01, kernel=rbf; total time=   7.4s
# [CV 1/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 1/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.8s
# [CV 2/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 2/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.8s
# [CV 3/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 3/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.9s
# [CV 4/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 4/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.9s
# [CV 5/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 5/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.7s
# [CV 6/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 6/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   6.1s
# [CV 7/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 7/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   6.1s
# [CV 8/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 8/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.5s
# [CV 9/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 9/10; 16/36] END ...........C=0.1, gamma=0.1, kernel=rbf; total time=   5.8s
# [CV 10/10; 16/36] START C=0.1, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 10/10; 16/36] END ..........C=0.1, gamma=0.1, kernel=rbf; total time=   5.4s
# [CV 1/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 1/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  11.4s
# [CV 2/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 2/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  11.5s
# [CV 3/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 3/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  10.8s
# [CV 4/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 4/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  12.7s
# [CV 5/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 5/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  13.1s
# [CV 6/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 6/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  12.0s
# [CV 7/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 7/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  12.4s
# [CV 8/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 8/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  14.5s
# [CV 9/10; 17/36] START C=0.1, gamma=1, kernel=rbf...............................
# [LibSVM][CV 9/10; 17/36] END .............C=0.1, gamma=1, kernel=rbf; total time=  12.7s
# [CV 10/10; 17/36] START C=0.1, gamma=1, kernel=rbf..............................
# [LibSVM][CV 10/10; 17/36] END ............C=0.1, gamma=1, kernel=rbf; total time=  12.8s
# [CV 1/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 1/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  15.0s
# [CV 2/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 2/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.4s
# [CV 3/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 3/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  14.4s
# [CV 4/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 4/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.1s
# [CV 5/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 5/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.3s
# [CV 6/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 6/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.4s
# [CV 7/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 7/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.3s
# [CV 8/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 8/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.1s
# [CV 9/10; 18/36] START C=0.1, gamma=10, kernel=rbf..............................
# [LibSVM][CV 9/10; 18/36] END ............C=0.1, gamma=10, kernel=rbf; total time=  13.5s
# [CV 10/10; 18/36] START C=0.1, gamma=10, kernel=rbf.............................
# [LibSVM][CV 10/10; 18/36] END ...........C=0.1, gamma=10, kernel=rbf; total time=  13.3s
# [CV 1/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 1/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.6s
# [CV 2/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 2/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.2s
# [CV 3/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 3/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 4/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 4/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.0s
# [CV 5/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 5/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.1s
# [CV 6/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 6/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.0s
# [CV 7/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 7/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.0s
# [CV 8/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 8/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 9/10; 19/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 9/10; 19/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 10/10; 19/36] START C=1, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 10/10; 19/36] END ...........C=1, gamma=0.01, kernel=rbf; total time=   3.8s
# [CV 1/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 1/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.5s
# [CV 2/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 2/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.2s
# [CV 3/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 3/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.4s
# [CV 4/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 4/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.8s
# [CV 5/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 5/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   8.0s
# [CV 6/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 6/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.3s
# [CV 7/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 7/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.4s
# [CV 8/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 8/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.6s
# [CV 9/10; 20/36] START C=1, gamma=0.001, kernel=rbf.............................
# [LibSVM][CV 9/10; 20/36] END ...........C=1, gamma=0.001, kernel=rbf; total time=   7.8s
# [CV 10/10; 20/36] START C=1, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 10/10; 20/36] END ..........C=1, gamma=0.001, kernel=rbf; total time=   7.6s
# [CV 1/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 1/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 2/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 2/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 3/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 3/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 4/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 4/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.1s
# [CV 5/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 5/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.1s
# [CV 6/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 6/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.0s
# [CV 7/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 7/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.1s
# [CV 8/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 8/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   4.3s
# [CV 9/10; 21/36] START C=1, gamma=0.01, kernel=rbf..............................
# [LibSVM][CV 9/10; 21/36] END ............C=1, gamma=0.01, kernel=rbf; total time=   3.8s
# [CV 10/10; 21/36] START C=1, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 10/10; 21/36] END ...........C=1, gamma=0.01, kernel=rbf; total time=   3.9s
# [CV 1/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 1/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.8s
# [CV 2/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 2/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   4.1s
# [CV 3/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 3/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.9s
# [CV 4/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 4/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.2s
# [CV 5/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 5/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.4s
# [CV 6/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 6/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.7s
# [CV 7/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 7/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.9s
# [CV 8/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 8/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.5s
# [CV 9/10; 22/36] START C=1, gamma=0.1, kernel=rbf...............................
# [LibSVM][CV 9/10; 22/36] END .............C=1, gamma=0.1, kernel=rbf; total time=   3.7s
# [CV 10/10; 22/36] START C=1, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 10/10; 22/36] END ............C=1, gamma=0.1, kernel=rbf; total time=   3.5s
# [CV 1/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 1/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  13.1s
# [CV 2/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 2/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  12.6s
# [CV 3/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 3/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  12.5s
# [CV 4/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 4/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  15.4s
# [CV 5/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 5/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  20.2s
# [CV 6/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 6/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  16.2s
# [CV 7/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 7/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  15.4s
# [CV 8/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 8/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  14.8s
# [CV 9/10; 23/36] START C=1, gamma=1, kernel=rbf.................................
# [LibSVM][CV 9/10; 23/36] END ...............C=1, gamma=1, kernel=rbf; total time=  13.9s
# [CV 10/10; 23/36] START C=1, gamma=1, kernel=rbf................................
# [LibSVM][CV 10/10; 23/36] END ..............C=1, gamma=1, kernel=rbf; total time=  13.4s
# [CV 1/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 1/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  14.9s
# [CV 2/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 2/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  14.9s
# [CV 3/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 3/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  15.0s
# [CV 4/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 4/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  12.7s
# [CV 5/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 5/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  12.5s
# [CV 6/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 6/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  12.7s
# [CV 7/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 7/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  12.6s
# [CV 8/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 8/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  12.7s
# [CV 9/10; 24/36] START C=1, gamma=10, kernel=rbf................................
# [LibSVM][CV 9/10; 24/36] END ..............C=1, gamma=10, kernel=rbf; total time=  12.3s
# [CV 10/10; 24/36] START C=1, gamma=10, kernel=rbf...............................
# [LibSVM][CV 10/10; 24/36] END .............C=1, gamma=10, kernel=rbf; total time=  12.5s
# [CV 1/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 1/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.3s
# [CV 2/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 2/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.4s
# [CV 3/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 3/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 4/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 4/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.3s
# [CV 5/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 5/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 6/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 6/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 7/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 7/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 8/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 8/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 9/10; 25/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 9/10; 25/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 10/10; 25/36] START C=10, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 10/10; 25/36] END ..........C=10, gamma=0.01, kernel=rbf; total time=   2.3s
# [CV 1/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 1/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 2/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 2/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 3/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 3/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 4/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 4/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 5/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 5/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.5s
# [CV 6/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 6/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 7/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 7/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.3s
# [CV 8/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 8/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 9/10; 26/36] START C=10, gamma=0.001, kernel=rbf............................
# [LibSVM][CV 9/10; 26/36] END ..........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 10/10; 26/36] START C=10, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 10/10; 26/36] END .........C=10, gamma=0.001, kernel=rbf; total time=   3.4s
# [CV 1/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 1/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 2/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 2/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 3/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 3/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 4/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 4/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 5/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 5/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 6/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 6/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.3s
# [CV 7/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 7/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 8/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 8/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 9/10; 27/36] START C=10, gamma=0.01, kernel=rbf.............................
# [LibSVM][CV 9/10; 27/36] END ...........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 10/10; 27/36] START C=10, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 10/10; 27/36] END ..........C=10, gamma=0.01, kernel=rbf; total time=   2.2s
# [CV 1/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 1/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 2/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 2/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.9s
# [CV 3/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 3/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.9s
# [CV 4/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 4/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 5/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 5/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 6/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 6/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 7/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 7/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 8/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 8/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 9/10; 28/36] START C=10, gamma=0.1, kernel=rbf..............................
# [LibSVM][CV 9/10; 28/36] END ............C=10, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 10/10; 28/36] START C=10, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 10/10; 28/36] END ...........C=10, gamma=0.1, kernel=rbf; total time=   2.7s
# [CV 1/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 1/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.5s
# [CV 2/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 2/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.8s
# [CV 3/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 3/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.9s
# [CV 4/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 4/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.8s
# [CV 5/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 5/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.6s
# [CV 6/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 6/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.8s
# [CV 7/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 7/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.6s
# [CV 8/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 8/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.9s
# [CV 9/10; 29/36] START C=10, gamma=1, kernel=rbf................................
# [LibSVM][CV 9/10; 29/36] END ..............C=10, gamma=1, kernel=rbf; total time=  11.9s
# [CV 10/10; 29/36] START C=10, gamma=1, kernel=rbf...............................
# [LibSVM][CV 10/10; 29/36] END .............C=10, gamma=1, kernel=rbf; total time=  11.8s
# [CV 1/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 1/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.5s
# [CV 2/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 2/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 3/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 3/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 4/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 4/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 5/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 5/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 6/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 6/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 7/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 7/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.8s
# [CV 8/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 8/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 9/10; 30/36] START C=10, gamma=10, kernel=rbf...............................
# [LibSVM][CV 9/10; 30/36] END .............C=10, gamma=10, kernel=rbf; total time=  12.6s
# [CV 10/10; 30/36] START C=10, gamma=10, kernel=rbf..............................
# [LibSVM][CV 10/10; 30/36] END ............C=10, gamma=10, kernel=rbf; total time=  12.8s
# [CV 1/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.3s
# [CV 2/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 3/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 4/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   1.9s
# [CV 5/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 6/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 7/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   1.9s
# [CV 8/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 9/10; 31/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 31/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 10/10; 31/36] START C=100, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 31/36] END .........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 1/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 1/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.2s
# [CV 2/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 2/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV 3/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 3/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV 4/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 4/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV 5/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 5/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV 6/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 6/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV 7/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 7/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV 8/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 8/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV 9/10; 32/36] START C=100, gamma=0.001, kernel=rbf...........................
# [LibSVM][CV 9/10; 32/36] END .........C=100, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV 10/10; 32/36] START C=100, gamma=0.001, kernel=rbf..........................
# [LibSVM][CV 10/10; 32/36] END ........C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV 1/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 1/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 2/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 2/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 3/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 3/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 4/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 4/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 5/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 5/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 6/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 6/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 7/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 7/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 8/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 8/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 9/10; 33/36] START C=100, gamma=0.01, kernel=rbf............................
# [LibSVM][CV 9/10; 33/36] END ..........C=100, gamma=0.01, kernel=rbf; total time=   2.1s
# [CV 10/10; 33/36] START C=100, gamma=0.01, kernel=rbf...........................
# [LibSVM][CV 10/10; 33/36] END .........C=100, gamma=0.01, kernel=rbf; total time=   2.0s
# [CV 1/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 1/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   3.0s
# [CV 2/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 2/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 3/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 3/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 4/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 4/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 5/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 5/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 6/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 6/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 7/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 7/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.8s
# [CV 8/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 8/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   3.0s
# [CV 9/10; 34/36] START C=100, gamma=0.1, kernel=rbf.............................
# [LibSVM][CV 9/10; 34/36] END ...........C=100, gamma=0.1, kernel=rbf; total time=   2.9s
# [CV 10/10; 34/36] START C=100, gamma=0.1, kernel=rbf............................
# [LibSVM][CV 10/10; 34/36] END ..........C=100, gamma=0.1, kernel=rbf; total time=   2.9s
# [CV 1/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 1/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  11.6s
# [CV 2/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 2/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  12.1s
# [CV 3/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 3/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  11.8s
# [CV 4/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 4/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  12.0s
# [CV 5/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 5/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  11.8s
# [CV 6/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 6/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  12.0s
# [CV 7/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 7/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  11.8s
# [CV 8/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 8/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  11.8s
# [CV 9/10; 35/36] START C=100, gamma=1, kernel=rbf...............................
# [LibSVM][CV 9/10; 35/36] END .............C=100, gamma=1, kernel=rbf; total time=  12.0s
# [CV 10/10; 35/36] START C=100, gamma=1, kernel=rbf..............................
# [LibSVM][CV 10/10; 35/36] END ............C=100, gamma=1, kernel=rbf; total time=  11.9s
# [CV 1/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 1/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  13.1s
# [CV 2/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 2/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.6s
# [CV 3/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 3/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.9s
# [CV 4/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 4/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.7s
# [CV 5/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 5/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.5s
# [CV 6/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 6/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.5s
# [CV 7/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 7/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.9s
# [CV 8/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 8/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  12.9s
# [CV 9/10; 36/36] START C=100, gamma=10, kernel=rbf..............................
# [LibSVM][CV 9/10; 36/36] END ............C=100, gamma=10, kernel=rbf; total time=  13.0s
# [CV 10/10; 36/36] START C=100, gamma=10, kernel=rbf.............................
# [LibSVM][CV 10/10; 36/36] END ...........C=100, gamma=10, kernel=rbf; total time=  12.9s
# [LibSVM]Best score = {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Param = 0.9602

# %%
mean_test_scores = np.array(gscv.cv_results_['mean_test_score']).reshape(len(C_test), len(gam_test))

# Plotting the heatmap with a different colormap ('viridis')
plt.figure(figsize=(8, 6))
heatmap = plt.imshow(mean_test_scores, interpolation='nearest', cmap='viridis')  # Use 'viridis' colormap
plt.xlabel('Gamma Index')
plt.ylabel('C Index')
plt.colorbar()

# Add text annotations for each cell
for i in range(len(C_test)):
    for j in range(len(gam_test)):
        plt.text(j, i, f'{mean_test_scores[i, j]:.3f}', ha='center', va='center', color='black')

plt.xticks(np.arange(len(gam_test)), gam_test, rotation=45)
plt.yticks(np.arange(len(C_test)), C_test)
plt.title('Grid Search Mean Test Accuracy')
best_index = np.unravel_index(np.argmax(mean_test_scores), mean_test_scores.shape)
plt.scatter(best_index[1], best_index[0], marker='o', color='red', s=100, label='Best Score')
plt.savefig('MeanTestAccuracy.pdf')

# %%
svc_rb = svm.SVC(kernel="rbf", C=10, gamma=0.1, verbose=0)
svc_rb.fit(X_train,y_train)
yhat_ts = svc_rb.predict(X_test)
acc_ts = np.mean(yhat_ts== y_test)
print('Accuracy = {0:f}'.format(acc_ts))
# Out:
# Accuracy = 0.959500

# %%
#save the model: you must use the .bz2 format for sklearn models!

model_savepath = 'model.bz2'
with bz2.BZ2File(model_savepath, 'w') as f:
    pickle.dump(svc_rb,f)

# %%
# generate kaggle submission file using the validation script
# !python {"validation.py " + model_savepath + " --Xts_path " + Xts_savepath + " --Xtr_path " + Xtr_savepath + " --yts_hat_path " + yts_hat_savepath }
# Out:
# training accuracy =  0.9915
# test label predictions saved in yts_hat_sklearn.csv
